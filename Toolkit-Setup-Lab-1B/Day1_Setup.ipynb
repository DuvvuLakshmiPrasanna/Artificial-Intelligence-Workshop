# %% [markdown]
# <a href="https://colab.research.google.com/github/DuvvuLakshmiPrasanna/Toolkit-Setup-Lab-1B/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the progression of AI proficiency, from foundational understanding to advanced development:
#
# *   **Layer 1: Data Fluency & Layer 2: AI Literacy:** The foundational understanding of data (collection, cleaning, interpreting) and what AI is, its capabilities, limitations, and ethical considerations.
# *   **Layer 3: Prompt Engineering:** The skill of crafting precise and effective inputs (prompts) to guide AI models for desired outputs and tasks.
# *   **Layer 4: AI Application & Tooling:** Proficiently using existing AI tools and platforms (e.g., ChatGPT, Midjourney, Copilot) to solve problems, automate tasks, and enhance workflows.
# *   **Layer 5: AI Development & Specialization:** The most advanced layer, involving building, training, deploying, and maintaining AI models and systems (e.g., data scientists, ML engineers).
